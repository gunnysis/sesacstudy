# %%
# %pip install gradio
# %pip install python-dotenv
# %pip install requests
# %pip install azure-cognitiveservices-speech
# %pip install openai
# %pip install ipywidgets
# Out:
# Requirement already satisfied: gradio in .\venv\Lib\site-packages (6.19.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in .\venv\Lib\site-packages (from gradio) (4.14.1)
# Requirement already satisfied: audioop-lts<=0.2.2 in .\venv\Lib\site-packages (from gradio) (0.2.2)
# Requirement already satisfied: brotli>=1.1.0 in .\venv\Lib\site-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in .\venv\Lib\site-packages (from gradio) (0.139.0)
# Requirement already satisfied: gradio-client==2.5.0 in .\venv\Lib\site-packages (from gradio) (2.5.0)
# Requirement already satisfied: groovy~=0.1 in .\venv\Lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: hf-gradio<1.0,>=0.4.1 in .\venv\Lib\site-packages (from gradio) (0.4.1)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in .\venv\Lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=1.2.0 in .\venv\Lib\site-packages (from gradio) (1.21.0)
# Requirement already satisfied: jinja2<4.0 in .\venv\Lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in .\venv\Lib\site-packages (from gradio) (3.0.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in .\venv\Lib\site-packages (from gradio) (2.5.0)
# Requirement already satisfied: orjson~=3.0 in .\venv\Lib\site-packages (from gradio) (3.11.9)
# Requirement already satisfied: packaging in .\venv\Lib\site-packages (from gradio) (26.2)
# Requirement already satisfied: pandas<4.0,>=1.0 in .\venv\Lib\site-packages (from gradio) (3.0.3)
# Requirement already satisfied: pillow<13.0,>=8.0 in .\venv\Lib\site-packages (from gradio) (12.3.0)
# Requirement already satisfied: pydantic<=3.0,>=2.0 in .\venv\Lib\site-packages (from gradio) (2.13.4)
# Requirement already satisfied: pydub<1.0 in .\venv\Lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart<1.0,>=0.0.18 in .\venv\Lib\site-packages (from gradio) (0.0.32)
# Requirement already satisfied: pytz>=2017.2 in .\venv\Lib\site-packages (from gradio) (2026.2)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in .\venv\Lib\site-packages (from gradio) (6.0.3)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in .\venv\Lib\site-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in .\venv\Lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<2.0,>=1.0.1 in .\venv\Lib\site-packages (from gradio) (1.3.1)
# Requirement already satisfied: tomlkit<0.15.0,>=0.12.0 in .\venv\Lib\site-packages (from gradio) (0.14.0)
# Requirement already satisfied: typer<1.0,>=0.12 in .\venv\Lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: typing-extensions~=4.0 in .\venv\Lib\site-packages (from gradio) (4.16.0)
# Requirement already satisfied: uvicorn>=0.14.0 in .\venv\Lib\site-packages (from gradio) (0.49.0)
# Requirement already satisfied: fsspec in .\venv\Lib\site-packages (from gradio-client==2.5.0->gradio) (2026.6.0)
# Requirement already satisfied: idna>=2.8 in .\venv\Lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.18)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\venv\Lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in .\venv\Lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in .\venv\Lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in .\venv\Lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in .\venv\Lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: click>=8.4.0 in .\venv\Lib\site-packages (from huggingface-hub<2.0,>=1.2.0->gradio) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in .\venv\Lib\site-packages (from huggingface-hub<2.0,>=1.2.0->gradio) (3.29.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in .\venv\Lib\site-packages (from huggingface-hub<2.0,>=1.2.0->gradio) (1.5.1)
# Requirement already satisfied: tqdm>=4.42.1 in .\venv\Lib\site-packages (from huggingface-hub<2.0,>=1.2.0->gradio) (4.68.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\venv\Lib\site-packages (from pandas<4.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\venv\Lib\site-packages (from pandas<4.0,>=1.0->gradio) (2026.2)
# Requirement already satisfied: annotated-types>=0.6.0 in .\venv\Lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in .\venv\Lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (2.46.4)
# Requirement already satisfied: shellingham>=1.3.0 in .\venv\Lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in .\venv\Lib\site-packages (from typer<1.0,>=0.12->gradio) (15.0.0)
# Requirement already satisfied: colorama in .\venv\Lib\site-packages (from click>=8.4.0->huggingface-hub<2.0,>=1.2.0->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in .\venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\venv\Lib\site-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\venv\Lib\site-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in .\venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: python-dotenv in .\venv\Lib\site-packages (1.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: requests in .\venv\Lib\site-packages (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\venv\Lib\site-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in .\venv\Lib\site-packages (from requests) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in .\venv\Lib\site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in .\venv\Lib\site-packages (from requests) (2026.6.17)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: azure-cognitiveservices-speech in .\venv\Lib\site-packages (1.50.0)
# Requirement already satisfied: azure-core>=1.33.0 in .\venv\Lib\site-packages (from azure-cognitiveservices-speech) (1.41.0)
# Requirement already satisfied: requests>=2.21.0 in .\venv\Lib\site-packages (from azure-core>=1.33.0->azure-cognitiveservices-speech) (2.34.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in .\venv\Lib\site-packages (from azure-core>=1.33.0->azure-cognitiveservices-speech) (4.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\venv\Lib\site-packages (from requests>=2.21.0->azure-core>=1.33.0->azure-cognitiveservices-speech) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in .\venv\Lib\site-packages (from requests>=2.21.0->azure-core>=1.33.0->azure-cognitiveservices-speech) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in .\venv\Lib\site-packages (from requests>=2.21.0->azure-core>=1.33.0->azure-cognitiveservices-speech) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in .\venv\Lib\site-packages (from requests>=2.21.0->azure-core>=1.33.0->azure-cognitiveservices-speech) (2026.6.17)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: openai in .\venv\Lib\site-packages (2.44.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in .\venv\Lib\site-packages (from openai) (4.14.1)
# Requirement already satisfied: distro<2,>=1.7.0 in .\venv\Lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in .\venv\Lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in .\venv\Lib\site-packages (from openai) (0.16.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in .\venv\Lib\site-packages (from openai) (2.13.4)
# Requirement already satisfied: sniffio in .\venv\Lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in .\venv\Lib\site-packages (from openai) (4.68.3)
# Requirement already satisfied: typing-extensions<5,>=4.14 in .\venv\Lib\site-packages (from openai) (4.16.0)
# Requirement already satisfied: idna>=2.8 in .\venv\Lib\site-packages (from anyio<5,>=3.5.0->openai) (3.18)
# Requirement already satisfied: certifi in .\venv\Lib\site-packages (from httpx<1,>=0.23.0->openai) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in .\venv\Lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in .\venv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in .\venv\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in .\venv\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\venv\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: colorama in .\venv\Lib\site-packages (from tqdm>4->openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: ipywidgets in .\venv\Lib\site-packages (8.1.8)
# Requirement already satisfied: comm>=0.1.3 in .\venv\Lib\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in .\venv\Lib\site-packages (from ipywidgets) (9.15.0)
# Requirement already satisfied: traitlets>=4.3.1 in .\venv\Lib\site-packages (from ipywidgets) (5.15.1)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in .\venv\Lib\site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in .\venv\Lib\site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: colorama>=0.4.4 in .\venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in .\venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in .\venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in .\venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in .\venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in .\venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: psutil>=7 in .\venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in .\venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in .\venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in .\venv\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.8.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in .\venv\Lib\site-packages (from jedi>=0.18.2->ipython>=6.1.0->ipywidgets) (0.8.7)
# Requirement already satisfied: executing>=1.2.0 in .\venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in .\venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in .\venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dotenv import load_dotenv
import gradio as gr
import os
import azure.cognitiveservices.speech as speechsdk
from openai import AzureOpenAI

load_dotenv()

# Azure OpenAI Setup
endpoint = os.getenv("AZURE_OPENAI_ENDPOINT")
if endpoint and "/openai/" in endpoint:
    endpoint = endpoint.split("/openai/")[0] + "/"

openai_client = AzureOpenAI(
    azure_endpoint=endpoint,
    api_key=os.getenv("AZURE_OPENAI_KEY"),
    api_version="2024-02-15-preview"
)
deployment_name = os.getenv("DEPLOY_NAME")

def request_stt(audio_path):
    api_key = os.getenv('SPEECH_KEY')
    region = os.getenv('REGION', "koreacentral")

    if audio_path is None:
        return ''

    speech_config = speechsdk.SpeechConfig(subscription=api_key, region=region)
    speech_config.speech_recognition_language = "ko-KR"

    audio_config = speechsdk.audio.AudioConfig(filename=audio_path)
    speech_recognizer = speechsdk.SpeechRecognizer(speech_config=speech_config, audio_config=audio_config)

    print("Recognizing speech...")
    result = speech_recognizer.recognize_once_async().get()

    if result.reason == speechsdk.ResultReason.RecognizedSpeech:
        print(f"Recognized: {result.text}")
        return result.text
    elif result.reason == speechsdk.ResultReason.NoMatch:
        print("No speech could be recognized")
        return ""
    elif result.reason == speechsdk.ResultReason.Canceled:
        cancellation_details = result.cancellation_details
        print("Speech Recognition canceled: {}".format(cancellation_details.reason))
        if cancellation_details.reason == speechsdk.CancellationReason.Error:
            print("Error details: {}".format(cancellation_details.error_details))
        return ""

    return ""

def chatgpt_response(prompt, history):
    # history 는 messages 형식(list[dict])이며, 비어 있을 수 있음
    if history is None:
        history = []

    prompt = (prompt or "").strip()
    if not prompt:
        # 입력이 없으면 상태를 그대로 유지
        return "", history

    messages = [{"role": "system", "content": "당신은 사용자에게 유용한 정보를 제공하는 친절한 AI 어시스턴트입니다."}]
    messages.extend(history)
    messages.append({"role": "user", "content": prompt})

    try:
        response = openai_client.chat.completions.create(
            model=deployment_name,
            messages=messages,
            max_completion_tokens=500
        )
        bot_message = response.choices[0].message.content
    except Exception as e:
        bot_message = f"오류 발생: {str(e)}"

    history = history + [
        {"role": "user", "content": prompt},
        {"role": "assistant", "content": bot_message},
    ]
    # 첫 번째 반환값으로 입력창을 비움
    return "", history

def change_audio(audio_path):
    print("Audio path:", audio_path)
    text = request_stt(audio_path=audio_path)
    return text

with gr.Blocks() as demo:
    gr.Markdown('<h2>Speech & OpenAI Chatbot</h2>')

    with gr.Row():
        with gr.Column(scale=1):
            gr.Markdown('<h3>STT (음성 인식)</h3>')
            input_mic = gr.Audio(
                label="마이크 입력", sources=["microphone"], type="filepath",
                waveform_options=gr.WaveformOptions(
                    waveform_color="#01C6FF",
                    waveform_progress_color="#01C6FF",
                    skip_length=2
                )
            )
            output_textbox = gr.Textbox(label="인식된 텍스트", placeholder="음성이 변환된 텍스트가 표시됩니다.")
            stt_send_button = gr.Button("인식된 텍스트로 전송", variant="primary")

        with gr.Column(scale=2):
            gr.Markdown('<h3>ChatGPT</h3>')
            chatbot = gr.Chatbot(label="채팅 내역")
            with gr.Row():
                user_input = gr.Textbox(show_label=False, placeholder="메시지를 입력하세요...", scale=8)
                submit_button = gr.Button("전송", scale=1)

            clear_btn = gr.Button("대화 지우기")

    # Events
    # 마이크 입력이 바뀌면 STT 실행 → 인식된 텍스트 표시
    input_mic.change(fn=change_audio, inputs=[input_mic], outputs=[output_textbox])

    # 인식된 텍스트를 OpenAI 로 전송 (전송 후 인식 텍스트박스는 비움)
    stt_send_button.click(fn=chatgpt_response, inputs=[output_textbox, chatbot], outputs=[output_textbox, chatbot])

    # 직접 입력한 텍스트를 OpenAI 로 전송
    submit_button.click(fn=chatgpt_response, inputs=[user_input, chatbot], outputs=[user_input, chatbot])
    user_input.submit(fn=chatgpt_response, inputs=[user_input, chatbot], outputs=[user_input, chatbot])
    clear_btn.click(lambda: [], None, chatbot, queue=False)

demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://241606e2451847efc3.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://241606e2451847efc3.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
