# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in F:\Projects\20260522\.venv\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=2.3.3 in F:\Projects\20260522\.venv\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in F:\Projects\20260522\.venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in F:\Projects\20260522\.venv\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in F:\Projects\20260522\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# %%
s = pd.Series([100, 50, 30, 10])
s
# Out:
# 0    100
# 1     50
# 2     30
# 3     10
# dtype: int64

# %%
s.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
s.index = ['A', 'B', 'O', 'AB']

# %%
s.index
# Out:
# Index(['A', 'B', 'O', 'AB'], dtype='str')

# %%
s
# Out:
# A     100
# B      50
# O      30
# AB     10
# dtype: int64

# %%
family = [['김철수', 45, '남', 175, 'A'],
          ['이영희', 43, '여', 168, 'B'],
          ['김선우', 13, '남', 160, 'A'],
          ['김지우', 10, '여', 140, 'O'],
          ['김현우',  7, '남', 125, 'AB']]

df = pd.DataFrame(family)
df
# Out:
#      0   1  2    3   4
# 0  김철수  45  남  175   A
# 1  이영희  43  여  168   B
# 2  김선우  13  남  160   A
# 3  김지우  10  여  140   O
# 4  김현우   7  남  125  AB

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.index = ['아빠', '엄마', '첫째', '둘째', '셋째']
df.index
# Out:
# Index(['아빠', '엄마', '첫째', '둘째', '셋째'], dtype='str')

# %%
df
# Out:
#       0   1  2    3   4
# 아빠  김철수  45  남  175   A
# 엄마  이영희  43  여  168   B
# 첫째  김선우  13  남  160   A
# 둘째  김지우  10  여  140   O
# 셋째  김현우   7  남  125  AB

# %%
df.columns
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.columns = ['이름', '나이', '성별', '키', '혈액형']
df.columns
# Out:
# Index(['이름', '나이', '성별', '키', '혈액형'], dtype='str')

# %%
df
# Out:
#      이름  나이 성별    키 혈액형
# 아빠  김철수  45  남  175   A
# 엄마  이영희  43  여  168   B
# 첫째  김선우  13  남  160   A
# 둘째  김지우  10  여  140   O
# 셋째  김현우   7  남  125  AB

# %%
d = {
    '이름': ['철수', '영희', '길동', '길순', '무개'],
    '나이': [15, 16, 20, 19, 23],
    '키': [160.5, 158.3, 175.0, 178.4, 185.0]
    }
df2 = pd.DataFrame(d)
df2
# Out:
#    이름  나이      키
# 0  철수  15  160.5
# 1  영희  16  158.3
# 2  길동  20  175.0
# 3  길순  19  178.4
# 4  무개  23  185.0

# %%
df3 = df2.copy()
df4 = df3.set_index('이름')
df4
# Out:
#     나이      키
# 이름
# 철수  15  160.5
# 영희  16  158.3
# 길동  20  175.0
# 길순  19  178.4
# 무개  23  185.0

# %%
df3
# Out:
#    이름  나이      키
# 0  철수  15  160.5
# 1  영희  16  158.3
# 2  길동  20  175.0
# 3  길순  19  178.4
# 4  무개  23  185.0

# %%
df3.set_index('이름', inplace=True)
df3
# Out:
#     나이      키
# 이름
# 철수  15  160.5
# 영희  16  158.3
# 길동  20  175.0
# 길순  19  178.4
# 무개  23  185.0

# %%
df4 = pd.read_csv('../data/scores.csv', encoding='cp949')
df4
# Out:
#      학번      이름 성별     국어   영어     수학
# 0  2201    kate  f  100.0   90   95.0
# 1  2202  olivia  f   90.0   80   75.0
# 2  2203    emma  f   95.0  100  100.0
# 3  2204  sophia  f  100.0  100  100.0
# 4  2205     amy  f    NaN   35   60.0
# 5  2206   james  m   70.0   75   65.0
# 6  2207  daniel  m   80.0   90   55.0
# 7  2208   peter  m   50.0   60    NaN
# 8  2209   kevin  m  100.0  100   90.0
# 9  2210    jack  m   90.0   95   70.0

# %%
df5 = pd.read_csv('../data/scores.csv', encoding='utf-8')
df5
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df5 = pd.read_csv('../data/scores.csv', encoding='utf-8')
#       2 df5
#
# File f:\Projects\20260522\.venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File f:\Projects\20260522\.venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File f:\Projects\20260522\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File f:\Projects\20260522\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1922, in TextFileReader._make_engine(self, f, engine)
#    1919     raise ValueError(msg)
#    1921 try:
# -> 1922     return mapping[engine](f, **self.options)
#    1923 except Exception:
#    1924     if self.handles is not None:
#
# File f:\Projects\20260522\.venv\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:95, in CParserWrapper.__init__(self, src, **kwds)
#      92 if kwds["dtype_backend"] == "pyarrow":
#      93     # Fail here loudly instead of in cython after reading
#      94     import_optional_dependency("pyarrow")
# ---> 95 self._reader = parsers.TextReader(src, **kwds)
#      97 self.unnamed_cols = self._reader.unnamed_cols
#      99 passed_names = self.names is None
#
# File pandas/_libs/parsers.pyx:568, in pandas._libs.parsers.TextReader.__cinit__()
# --> 568 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/parsers.pyx:685, in pandas._libs.parsers.TextReader._get_header()
# --> 685 'Could not get source, probably due dynamically evaluated source code.'
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc7 in position 0: invalid continuation byte

# %%
df4.set_index('학번', inplace=True)
df4
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2201    kate  f  100.0   90   95.0
# 2202  olivia  f   90.0   80   75.0
# 2203    emma  f   95.0  100  100.0
# 2204  sophia  f  100.0  100  100.0
# 2205     amy  f    NaN   35   60.0
# 2206   james  m   70.0   75   65.0
# 2207  daniel  m   80.0   90   55.0
# 2208   peter  m   50.0   60    NaN
# 2209   kevin  m  100.0  100   90.0
# 2210    jack  m   90.0   95   70.0

# %%
df4.shape
# Out:
# (10, 5)

# %%
df4.dtypes
# Out:
# 이름        str
# 성별        str
# 국어    float64
# 영어      int64
# 수학    float64
# dtype: object

# %%
df4.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 2201 to 2210
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      10 non-null     str
#  1   성별      10 non-null     str
#  2   국어      9 non-null      float64
#  3   영어      10 non-null     int64
#  4   수학      9 non-null      float64
# dtypes: float64(2), int64(1), str(2)
# memory usage: 532.0 bytes

# %%
df4.describe()
# Out:
#                국어          영어          수학
# count    9.000000   10.000000    9.000000
# mean    86.111111   82.500000   78.888889
# std     16.914819   21.114766   17.638342
# min     50.000000   35.000000   55.000000
# 25%     80.000000   76.250000   65.000000
# 50%     90.000000   90.000000   75.000000
# 75%    100.000000   98.750000   95.000000
# max    100.000000  100.000000  100.000000

# %%
df4['영어'].median()
# Out:
# np.float64(90.0)

# %%
df4.value_counts('국어')
# Out:
# 국어
# 100.0    3
# 90.0     2
# 95.0     1
# 70.0     1
# 80.0     1
# 50.0     1
# Name: count, dtype: int64

# %%
df4.sort_index(ascending=False)
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2210    jack  m   90.0   95   70.0
# 2209   kevin  m  100.0  100   90.0
# 2208   peter  m   50.0   60    NaN
# 2207  daniel  m   80.0   90   55.0
# 2206   james  m   70.0   75   65.0
# 2205     amy  f    NaN   35   60.0
# 2204  sophia  f  100.0  100  100.0
# 2203    emma  f   95.0  100  100.0
# 2202  olivia  f   90.0   80   75.0
# 2201    kate  f  100.0   90   95.0

# %%
df4.sort_values('수학')
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2207  daniel  m   80.0   90   55.0
# 2205     amy  f    NaN   35   60.0
# 2206   james  m   70.0   75   65.0
# 2210    jack  m   90.0   95   70.0
# 2202  olivia  f   90.0   80   75.0
# 2209   kevin  m  100.0  100   90.0
# 2201    kate  f  100.0   90   95.0
# 2204  sophia  f  100.0  100  100.0
# 2203    emma  f   95.0  100  100.0
# 2208   peter  m   50.0   60    NaN

# %%
df4['이름']
# Out:
# 학번
# 2201      kate
# 2202    olivia
# 2203      emma
# 2204    sophia
# 2205       amy
# 2206     james
# 2207    daniel
# 2208     peter
# 2209     kevin
# 2210      jack
# Name: 이름, dtype: str

# %%
type(df4['이름'])
# Out:
# pandas.Series

# %%
df4.loc[2204]
# Out:
# 이름    sophia
# 성별         f
# 국어     100.0
# 영어       100
# 수학     100.0
# Name: 2204, dtype: object

# %%
df4.loc[2204, '이름']
# Out:
# 'sophia'

# %%
df4.iloc[0, 2]
# Out:
# np.float64(100.0)

# %%
df4.head(3)
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2201    kate  f  100.0   90   95.0
# 2202  olivia  f   90.0   80   75.0
# 2203    emma  f   95.0  100  100.0

# %%
df4.loc[2201]
# Out:
# 이름     kate
# 성별        f
# 국어    100.0
# 영어       90
# 수학     95.0
# Name: 2201, dtype: object

# %%
df4.loc[[2201]]
# Out:
#         이름 성별     국어  영어    수학
# 학번
# 2201  kate  f  100.0  90  95.0

# %%
df4.loc[[2201, 2202]]
# Out:
#           이름 성별     국어  영어    수학
# 학번
# 2201    kate  f  100.0  90  95.0
# 2202  olivia  f   90.0  80  75.0

# %%
df4.loc[2201, '영어']
# Out:
# np.int64(90)

# %%
df4.loc[2201, 2202]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File f:\Projects\20260522\.venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 2202
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df4.loc[2201, 2202]
#
# File f:\Projects\20260522\.venv\Lib\site-packages\pandas\core\indexing.py:1199, in _LocationIndexer.__getitem__(self, key)
#    1197     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1198     if self._is_scalar_access(key):
# -> 1199         return self.obj._get_value(*key, takeable=self._takeable)
#    1200     return self._getitem_tuple(key)
#    1201 else:
#    1202     # we by definition only have the 0th axis
#
# File f:\Projects\20260522\.venv\Lib\site-packages\pandas\core\frame.py:4489, in DataFrame._get_value(self, index, col, takeable)
#    4486     series = self._ixs(col, axis=1)
#    4487     return series._values[index]
# -> 4489 series = self._get_item(col)
#    4491 if not isinstance(self.index, MultiIndex):
#    4492     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    4493     #  results if our categories are integers that dont match our codes
#    4494     # IntervalIndex: IntervalTree has no get_loc
#    4495     row = self.index.get_loc(index)
#
# File f:\Projects\20260522\.venv\Lib\site-packages\pandas\core\frame.py:4967, in DataFrame._get_item(self, item)
#    4966 def _get_item(self, item: Hashable) -> Series:
# -> 4967     loc = self.columns.get_loc(item)
#    4968     return self._ixs(loc, axis=1)
#
# File f:\Projects\20260522\.venv\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 2202

# %%
df4.loc[2201:2203]
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2201    kate  f  100.0   90   95.0
# 2202  olivia  f   90.0   80   75.0
# 2203    emma  f   95.0  100  100.0

# %%
df4.loc[2202, ['영어', '수학']]
# Out:
# 영어    80.0
# 수학    75.0
# Name: 2202, dtype: float64

# %%
df4.loc[2202:2205, ['영어', '수학']]
# Out:
#        영어     수학
# 학번
# 2202   80   75.0
# 2203  100  100.0
# 2204  100  100.0
# 2205   35   60.0

# %%
df4.loc[[2202, 2210], ['영어', '수학']]
# Out:
#       영어    수학
# 학번
# 2202  80  75.0
# 2210  95  70.0

# %%
df4.iloc[0]
# Out:
# 이름     kate
# 성별        f
# 국어    100.0
# 영어       90
# 수학     95.0
# Name: 2201, dtype: object

# %%
df4.iloc[2:5,[4, 2, 0]]
# Out:
#          수학     국어      이름
# 학번
# 2203  100.0   95.0    emma
# 2204  100.0  100.0  sophia
# 2205   60.0    NaN     amy

# %%
df4.head(3)
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2201    kate  f  100.0   90   95.0
# 2202  olivia  f   90.0   80   75.0
# 2203    emma  f   95.0  100  100.0

# %%
df4['영어']
# Out:
# 학번
# 2201     90
# 2202     80
# 2203    100
# 2204    100
# 2205     35
# 2206     75
# 2207     90
# 2208     60
# 2209    100
# 2210     95
# Name: 영어, dtype: int64

# %%
df4[['영어', '수학']]
# Out:
#        영어     수학
# 학번
# 2201   90   95.0
# 2202   80   75.0
# 2203  100  100.0
# 2204  100  100.0
# 2205   35   60.0
# 2206   75   65.0
# 2207   90   55.0
# 2208   60    NaN
# 2209  100   90.0
# 2210   95   70.0

# %%
df4.loc[2203, ['국어', '영어', '수학']]
# Out:
# 국어     95.0
# 영어    100.0
# 수학    100.0
# Name: 2203, dtype: float64

# %%
df4.loc[[2201, 2205], ['이름']]
# Out:
#         이름
# 학번
# 2201  kate
# 2205   amy

# %%
df4.loc[[2201, 2205], '이름']
# Out:
# 학번
# 2201    kate
# 2205     amy
# Name: 이름, dtype: str

# %%
df4.loc[[2201, 2205], ['이름', '수학']]
# Out:
#         이름    수학
# 학번
# 2201  kate  95.0
# 2205   amy  60.0

# %%
df4.loc[df4['국어']==100]
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2201    kate  f  100.0   90   95.0
# 2204  sophia  f  100.0  100  100.0
# 2209   kevin  m  100.0  100   90.0

# %%
df4.loc[df4['국어']==100, ['이름','성별','국어']]
# Out:
#           이름 성별     국어
# 학번
# 2201    kate  f  100.0
# 2204  sophia  f  100.0
# 2209   kevin  m  100.0

# %%
df4.loc[(df4['국어']==100) & (df4['영어']==100) & (df4['수학']==100)]
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2204  sophia  f  100.0  100  100.0

# %%
df4.loc[(df4['국어']==100) | (df4['영어']==100) | (df4['수학']==100)]
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2201    kate  f  100.0   90   95.0
# 2203    emma  f   95.0  100  100.0
# 2204  sophia  f  100.0  100  100.0
# 2209   kevin  m  100.0  100   90.0

# %%
df4['평균'] = round((df4['국어'] + df4['영어'] + df4['수학'])/3, 1)
df4
# Out:
#           이름 성별     국어   영어     수학     평균
# 학번
# 2201    kate  f  100.0   90   95.0   95.0
# 2202  olivia  f   90.0   80   75.0   81.7
# 2203    emma  f   95.0  100  100.0   98.3
# 2204  sophia  f  100.0  100  100.0  100.0
# 2205     amy  f    NaN   35   60.0    NaN
# 2206   james  m   70.0   75   65.0   70.0
# 2207  daniel  m   80.0   90   55.0   75.0
# 2208   peter  m   50.0   60    NaN    NaN
# 2209   kevin  m  100.0  100   90.0   96.7
# 2210    jack  m   90.0   95   70.0   85.0

# %%
df4.drop(columns=['평균'])
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2201    kate  f  100.0   90   95.0
# 2202  olivia  f   90.0   80   75.0
# 2203    emma  f   95.0  100  100.0
# 2204  sophia  f  100.0  100  100.0
# 2205     amy  f    NaN   35   60.0
# 2206   james  m   70.0   75   65.0
# 2207  daniel  m   80.0   90   55.0
# 2208   peter  m   50.0   60    NaN
# 2209   kevin  m  100.0  100   90.0
# 2210    jack  m   90.0   95   70.0

# %%
df4
# Out:
#           이름 성별     국어   영어     수학     평균
# 학번
# 2201    kate  f  100.0   90   95.0   95.0
# 2202  olivia  f   90.0   80   75.0   81.7
# 2203    emma  f   95.0  100  100.0   98.3
# 2204  sophia  f  100.0  100  100.0  100.0
# 2205     amy  f    NaN   35   60.0    NaN
# 2206   james  m   70.0   75   65.0   70.0
# 2207  daniel  m   80.0   90   55.0   75.0
# 2208   peter  m   50.0   60    NaN    NaN
# 2209   kevin  m  100.0  100   90.0   96.7
# 2210    jack  m   90.0   95   70.0   85.0

# %%
df4.isnull().sum()
# Out:
# 이름    0
# 성별    0
# 국어    1
# 영어    0
# 수학    1
# 평균    2
# dtype: int64

# %%
df4.dropna()
# Out:
#           이름 성별     국어   영어     수학     평균
# 학번
# 2201    kate  f  100.0   90   95.0   95.0
# 2202  olivia  f   90.0   80   75.0   81.7
# 2203    emma  f   95.0  100  100.0   98.3
# 2204  sophia  f  100.0  100  100.0  100.0
# 2206   james  m   70.0   75   65.0   70.0
# 2207  daniel  m   80.0   90   55.0   75.0
# 2209   kevin  m  100.0  100   90.0   96.7
# 2210    jack  m   90.0   95   70.0   85.0

# %%
df4
# Out:
#           이름 성별     국어   영어     수학     평균
# 학번
# 2201    kate  f  100.0   90   95.0   95.0
# 2202  olivia  f   90.0   80   75.0   81.7
# 2203    emma  f   95.0  100  100.0   98.3
# 2204  sophia  f  100.0  100  100.0  100.0
# 2205     amy  f    NaN   35   60.0    NaN
# 2206   james  m   70.0   75   65.0   70.0
# 2207  daniel  m   80.0   90   55.0   75.0
# 2208   peter  m   50.0   60    NaN    NaN
# 2209   kevin  m  100.0  100   90.0   96.7
# 2210    jack  m   90.0   95   70.0   85.0

# %%
df4.ffill()
# Out:
#           이름 성별     국어   영어     수학     평균
# 학번
# 2201    kate  f  100.0   90   95.0   95.0
# 2202  olivia  f   90.0   80   75.0   81.7
# 2203    emma  f   95.0  100  100.0   98.3
# 2204  sophia  f  100.0  100  100.0  100.0
# 2205     amy  f  100.0   35   60.0  100.0
# 2206   james  m   70.0   75   65.0   70.0
# 2207  daniel  m   80.0   90   55.0   75.0
# 2208   peter  m   50.0   60   55.0   75.0
# 2209   kevin  m  100.0  100   90.0   96.7
# 2210    jack  m   90.0   95   70.0   85.0

# %%
df4.bfill()
# Out:
#           이름 성별     국어   영어     수학     평균
# 학번
# 2201    kate  f  100.0   90   95.0   95.0
# 2202  olivia  f   90.0   80   75.0   81.7
# 2203    emma  f   95.0  100  100.0   98.3
# 2204  sophia  f  100.0  100  100.0  100.0
# 2205     amy  f   70.0   35   60.0   70.0
# 2206   james  m   70.0   75   65.0   70.0
# 2207  daniel  m   80.0   90   55.0   75.0
# 2208   peter  m   50.0   60   90.0   96.7
# 2209   kevin  m  100.0  100   90.0   96.7
# 2210    jack  m   90.0   95   70.0   85.0

# %%
df4.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 2201 to 2210
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      10 non-null     str
#  1   성별      10 non-null     str
#  2   국어      9 non-null      float64
#  3   영어      10 non-null     int64
#  4   수학      9 non-null      float64
#  5   평균      8 non-null      float64
# dtypes: float64(3), int64(1), str(2)
# memory usage: 612.0 bytes

# %%
df4.astype({'영어':'float64'})
# Out:
#           이름 성별     국어     영어     수학     평균
# 학번
# 2201    kate  f  100.0   90.0   95.0   95.0
# 2202  olivia  f   90.0   80.0   75.0   81.7
# 2203    emma  f   95.0  100.0  100.0   98.3
# 2204  sophia  f  100.0  100.0  100.0  100.0
# 2205     amy  f    NaN   35.0   60.0    NaN
# 2206   james  m   70.0   75.0   65.0   70.0
# 2207  daniel  m   80.0   90.0   55.0   75.0
# 2208   peter  m   50.0   60.0    NaN    NaN
# 2209   kevin  m  100.0  100.0   90.0   96.7
# 2210    jack  m   90.0   95.0   70.0   85.0

# %%
df4
# Out:
#           이름 성별     국어   영어     수학     평균
# 학번
# 2201    kate  f  100.0   90   95.0   95.0
# 2202  olivia  f   90.0   80   75.0   81.7
# 2203    emma  f   95.0  100  100.0   98.3
# 2204  sophia  f  100.0  100  100.0  100.0
# 2205     amy  f    NaN   35   60.0    NaN
# 2206   james  m   70.0   75   65.0   70.0
# 2207  daniel  m   80.0   90   55.0   75.0
# 2208   peter  m   50.0   60    NaN    NaN
# 2209   kevin  m  100.0  100   90.0   96.7
# 2210    jack  m   90.0   95   70.0   85.0

# %%
# df4.astype({'영어':'float64'}, inplace=True)
# df4 = df4.astype({'영어':'float64'})

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in F:\Projects\20260522\.venv\Lib\site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in F:\Projects\20260522\.venv\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in F:\Projects\20260522\.venv\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in F:\Projects\20260522\.venv\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in F:\Projects\20260522\.venv\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in F:\Projects\20260522\.venv\Lib\site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in F:\Projects\20260522\.venv\Lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in F:\Projects\20260522\.venv\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in F:\Projects\20260522\.venv\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in F:\Projects\20260522\.venv\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in F:\Projects\20260522\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import matplotlib.pyplot as plt

# %%
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)

# %%
pd.Series([-1, 2, 3]).plot(title='테스트', figsize=(3, 2))
# Out:
# <Axes: title={'center': '테스트'}>

# %%
pd.Series([-1, 2, 3]).plot(title='테스트', figsize=(3, 2))
pass

# %%
df4.plot(kind='bar', y='국어', figsize=(4,3), color='red', title='국어점수')
pass
